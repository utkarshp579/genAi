# %%
from dotenv import load_dotenv
import os 
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
google_api_key = os.getenv("GOOGLE_API_KEY")
# Out:
# python-dotenv could not parse statement starting at line 21

# %%
os.environ["GOOGLE_API_KEY"] = google_api_key
# llm_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
# prompts = [
#     ("system" , "You are python developer."),
#     ("user" , "How to sort the array?")
# ]

# prompts = [
#     {"role" : "system" , "content" : "You are a Hindi translator." },
#     {"role" : "user" , "content" : "I love to play Cricket. "}
# ]

# %%
# response = llm_model.invoke(prompts)
# print(response.content)

# %% [markdown]
# ### Prompt Template

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
out = StrOutputParser()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role" : "system" , "content" : "You are a {language} translator." },
    {"role" : "user" , "content" : "{query}"},
])

# %%
# My self chain Node

def transform_case(result : str):
    return result.upper()

# %%
# final_prompts = prompts.format_messages(language="Hindi" ,
#                                         query = "I love GenerativeAI.")

# prompts.invoke({"language":"Hindi" ,
#                  "query" : "I love GenerativeAI."})
# res = llm.invoke(final_prompts)  
# print(res.content)

# %% [markdown]
# # We can invoke prompts and llm both. Then they both are runnables. We can connect runnables and connect them in series.

# %%
# prompts.invoke({"language" : "Hindi" , "query" : "I love GenerativeAI."}).messages

# %%
# This is Chaning. Inner will be solved and served as input for the next one. 
# 
#  res = llm.invoke(prompts.invoke({"language" : "Hindi" , "query" : "I love GenerativeAI."}).messages)
# res.content

# %%
chains = prompts | llm | out | transform_case
res = chains.invoke({"language":"Hinglish" , "query":"I am Indian."})
print(res)
# Out:
# NAMASTE! I'M HERE TO HELP YOU TRANSLATE BETWEEN ENGLISH AND HINGLISH.
#
# SO, YOU'RE INDIAN. THAT'S GREAT!
#
# WHAT CAN I TRANSLATE FOR YOU TODAY? DO YOU HAVE SOME ENGLISH YOU WANT TO SAY IN HINGLISH, OR SOME HINGLISH YOU WANT TO UNDERSTAND IN ENGLISH? JUST LET ME KNOW!
