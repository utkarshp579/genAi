# %% [markdown]
# #### Load Env Variables

# %%
from dotenv import load_dotenv
import os 
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
load_dotenv()
google_api_key = os.getenv("GOOGLE_API_KEY")
# Out:
# python-dotenv could not parse statement starting at line 21

# %%
os.environ["GOOGLE_API_KEY"] = google_api_key
llm_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
response = llm_model.invoke("Why do parrots talk?")
print(response)
# Out:
# content='Parrots talk for a fascinating combination of reasons, primarily driven by their **intelligence, social nature, and a specific vocal anatomy**. It\'s not just about mimicking sounds; it\'s a complex behavior with evolutionary and social roots.\n\nHere\'s a breakdown of the key reasons:\n\n**1. Social Bonding and Communication:**\n\n*   **Flock Animals:** Parrots are highly social creatures that live in flocks in the wild. Communication is vital for group cohesion, warning of predators, finding food, and maintaining social hierarchies.\n*   **Mimicry as a Social Tool:** In their natural environment, parrots often mimic sounds of their surroundings, including other birds, insects, and even environmental noises. This ability to mimic helps them blend in, identify members of their flock, and communicate within the group.\n*   **Strengthening Bonds:** In a flock, individuals might learn each other\'s calls and even develop unique "family" calls. This mimicry helps reinforce social bonds and creates a sense of belonging.\n\n**2. Intelligence and Cognitive Abilities:**\n\n*   **High Intelligence:** Parrots are among the most intelligent birds, with some species rivaling primates in their cognitive abilities. They have excellent memory, problem-solving skills, and the capacity for learning.\n*   **Understanding and Association:** While not all "talking" is true understanding, many parrots can learn to associate words and phrases with specific objects, actions, or people. They can learn to "ask" for things, greet their owners, or react to commands.\n*   **Intentionality:** Some research suggests that certain parrots can use vocalizations intentionally to communicate their needs or desires, rather than just randomly mimicking.\n\n**3. Vocal Anatomy and Physiology:**\n\n*   **Syrinx:** Parrots possess a specialized vocal organ called the syrinx, located at the base of their trachea. This organ is remarkably complex and allows for a wide range of vocalizations, including the ability to produce intricate sounds and mimic human speech.\n*   **Tongue and Beak:** Their thick, fleshy tongues and strong beaks act as articulators, allowing them to shape sounds and produce distinct words and phrases.\n\n**4. Learning and Reinforcement (in captivity):**\n\n*   **Observational Learning:** In captivity, parrots observe their human companions and learn to mimic the sounds they hear most frequently. This is a form of observational learning.\n*   **Positive Reinforcement:** Owners often unintentionally (or intentionally) reward their parrots for "talking" with attention, praise, or treats. This positive reinforcement encourages the parrot to repeat the learned sounds.\n*   **Seeking Attention:** Parrots are intelligent and often crave interaction. Talking can be a way for them to get their owner\'s attention, especially if they feel bored or neglected.\n\n**5. Playfulness and Exploration:**\n\n*   **Curiosity:** Parrots are naturally curious and enjoy exploring their environment, including sounds. Mimicking sounds can be a form of play and experimentation.\n*   **Entertainment:** For parrots, making noise and mimicking sounds can simply be fun.\n\n**In summary, parrots talk because:**\n\n*   **It\'s in their evolutionary nature:** Mimicry and vocal communication are essential for their survival and social structure in the wild.\n*   **They are highly intelligent:** They have the cognitive capacity to learn, associate, and even potentially understand context.\n*   **They have the physical tools:** Their syrinx, tongue, and beak are perfectly suited for producing complex sounds.\n*   **They are social beings:** They seek connection and interaction, and vocalization is a primary way they achieve this, especially with their human flock.\n\nIt\'s important to remember that while parrots can mimic human speech, their level of understanding varies greatly between individuals and species. Some are exceptional at associating words with meaning, while o ...
